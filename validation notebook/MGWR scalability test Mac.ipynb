# %% [markdown]
# Test for MGWR scalability on a Mac with 2 GHz Quad-Core Intel Core i5 based on 5k Zillow records.

# %%
# !fastgwr --version
# Out:
# fastgwr, version 0.2.8

# %% [markdown]
# Performance of `fastgwr` with 1 processor

# %%
# !fastgwr run -np 1 -data https://raw.github.com/Ziqi-Li/FastGWR/master/Zillow-test-dataset/zillow_5k.csv -mgwr
# Out:
# ------------------------------------------------------------
# Starting FastGWR with 1 Processors
# Spatial Kernel: Adaptive Bisquare
# Data Input Path: https://raw.github.com/Ziqi-Li/FastGWR/master/Zillow-test-dataset/zillow_5k.csv
# Output Result Path: fastgwr_rslt.csv
# Constant: True
# MGWR Backfitting...
# Data are standardized
# Initialization Done...
# Iter: 1 SOC: 2.74e-03
# bws: [135.0, 44.0, 137.0, 99.0, 117.0]
# Iter: 2 SOC: 1.71e-03
# bws: [261.0, 44.0, 165.0, 118.0, 213.0]
# Iter: 3 SOC: 9.55e-04
# bws: [344.0, 44.0, 195.0, 119.0, 305.0]
# Iter: 4 SOC: 6.07e-04
# bws: [402.0, 44.0, 234.0, 124.0, 384.0]
# Iter: 5 SOC: 5.09e-04
# bws: [445.0, 44.0, 259.0, 135.0, 500.0]
# Iter: 6 SOC: 4.68e-04
# bws: [445.0, 44.0, 259.0, 137.0, 781.0]
# Iter: 7 SOC: 4.38e-04
# bws: [445.0, 44.0, 295.0, 147.0, 1057.0]
# Iter: 8 SOC: 3.48e-04
# bws: [415.0, 44.0, 295.0, 151.0, 1299.0]
# Iter: 9 SOC: 3.12e-04
# bws: [415.0, 44.0, 295.0, 151.0, 2164.0]
# Iter: 10 SOC: 2.88e-04
# ...

# %% [markdown]
# Performance of `fastgwr` with 2 processors

# %%
# !fastgwr run -np 2 -data https://raw.github.com/Ziqi-Li/FastGWR/master/Zillow-test-dataset/zillow_5k.csv -mgwr
# Out:
# ------------------------------------------------------------
# Starting FastGWR with 2 Processors
# Spatial Kernel: Adaptive Bisquare
# Data Input Path: https://raw.github.com/Ziqi-Li/FastGWR/master/Zillow-test-dataset/zillow_5k.csv
# Output Result Path: fastgwr_rslt.csv
# Constant: True
# MGWR Backfitting...
# Data are standardized
# Initialization Done...
# Iter: 1 SOC: 2.74e-03
# bws: [135.0, 44.0, 137.0, 99.0, 117.0]
# Iter: 2 SOC: 1.71e-03
# bws: [261.0, 44.0, 165.0, 118.0, 213.0]
# Iter: 3 SOC: 9.55e-04
# bws: [344.0, 44.0, 195.0, 119.0, 305.0]
# Iter: 4 SOC: 6.07e-04
# bws: [402.0, 44.0, 234.0, 124.0, 384.0]
# Iter: 5 SOC: 5.09e-04
# bws: [445.0, 44.0, 259.0, 135.0, 500.0]
# Iter: 6 SOC: 4.68e-04
# bws: [445.0, 44.0, 259.0, 137.0, 781.0]
# Iter: 7 SOC: 4.38e-04
# bws: [445.0, 44.0, 295.0, 147.0, 1057.0]
# Iter: 8 SOC: 3.48e-04
# bws: [415.0, 44.0, 295.0, 151.0, 1299.0]
# Iter: 9 SOC: 3.12e-04
# bws: [415.0, 44.0, 295.0, 151.0, 2164.0]
# Iter: 10 SOC: 2.88e-04
# ...

# %% [markdown]
# Performance of `fastgwr` with 4 processors

# %%
# !fastgwr run -np 4 -data https://raw.github.com/Ziqi-Li/FastGWR/master/Zillow-test-dataset/zillow_5k.csv -mgwr
# Out:
# ------------------------------------------------------------
# Starting FastGWR with 4 Processors
# Spatial Kernel: Adaptive Bisquare
# Data Input Path: https://raw.github.com/Ziqi-Li/FastGWR/master/Zillow-test-dataset/zillow_5k.csv
# Output Result Path: fastgwr_rslt.csv
# Constant: True
# MGWR Backfitting...
# Data are standardized
# Initialization Done...
# Iter: 1 SOC: 2.74e-03
# bws: [135.0, 44.0, 137.0, 99.0, 117.0]
# Iter: 2 SOC: 1.71e-03
# bws: [261.0, 44.0, 165.0, 118.0, 213.0]
# Iter: 3 SOC: 9.55e-04
# bws: [344.0, 44.0, 195.0, 119.0, 305.0]
# Iter: 4 SOC: 6.07e-04
# bws: [402.0, 44.0, 234.0, 124.0, 384.0]
# Iter: 5 SOC: 5.09e-04
# bws: [445.0, 44.0, 259.0, 135.0, 500.0]
# Iter: 6 SOC: 4.68e-04
# bws: [445.0, 44.0, 259.0, 137.0, 781.0]
# Iter: 7 SOC: 4.38e-04
# bws: [445.0, 44.0, 295.0, 147.0, 1057.0]
# Iter: 8 SOC: 3.48e-04
# bws: [415.0, 44.0, 295.0, 151.0, 1299.0]
# Iter: 9 SOC: 3.12e-04
# bws: [415.0, 44.0, 295.0, 151.0, 2164.0]
# Iter: 10 SOC: 2.88e-04
# ...
